# %%
try:
    first=int(input('First: '))
    second=int(input('Second: '))
    sum=first+second
    print(f'Sum:{sum}')
except ValueError:
    print('enter no')
# Out:
# First: 12.1
# enter no

# %%
class Vehicle:
    def __init__(self,mileage,max_speed):
        self.mileage=mileage
        self.max_speed=max_speed
    color='white'
    
class Bus(Vehicle):
    def __init__(self,capacity):
        self.capacity=capacity
    def atribut(self):
        #fare calculation
        fare=self.capacity*100
        print('')
    
    

bus=Vehicle(10,20)
bus.seating_capacity=int(input('enter capacity'))
bus.name='Volvo'
bus.fare=bus.seating_capacity*100*1.1
print(bus.name,bus.max_speed,bus.mileage,bus.color,bus.fare)
# Out:
# enter capacity12
# Volvo 20 10 white 1320.0

# %%
import pandas as pd
#data= 
fruits = pd.DataFrame({"Apples":[30],"Bananas":[21]})
fruits
# Out:
#    Apples  Bananas
# 0      30       21

# %%
import csv
with open(filename,'w') as csvfile:
    csvwriter=csv.append()

# %%
import pandas as pd
import json
from urllib.request import urlopen

def get_clp_places(url):
    json_url = urllib.request.urlopen(url)
    data = json.loads(json_url.read())
    df = pd.json_normalize(data)
    return df

df_clp = get_clp_places("https://ecgplacesmw.colruytgroup.com/ecgplacesmw/v3/nl/places/filter/clp-places")
#a=df_clp.loc[:,'geoCoordinates.latitude']

# %%
import pandas as pd,json,urllib

url='https://ecgplacesmw.colruytgroup.com/ecgplacesmw/v3/nl/places/filter/clp-places'
json_url = urllib.request.urlopen(url)
data = json.loads(json_url.read())
df = pd.json_normalize(data)
#df[df.isin(['Antwerp']).any(1)]
df.head(5)
# Out:
#    placeId       commercialName branchId sourceStatus      sellingPartners  \
# 0      902      AALST (COLRUYT)     4156           AC  [QUALITY, 3RDPARTY]
# 1      946     AALTER (COLRUYT)     4218           AC  [QUALITY, 3RDPARTY]
# 2      950   AARSCHOT (COLRUYT)     4222           AC  [QUALITY, 3RDPARTY]
# 3      886  ALSEMBERG (COLRUYT)     4138           AC  [QUALITY, 3RDPARTY]
# 4      783       AMAY (COLRUYT)     3853           AC  [QUALITY, 3RDPARTY]
#
#                    handoverServices  \
# 0  [CSOP_ORDERABLE, PREPAID_PARCEL]
# 1  [CSOP_ORDERABLE, PREPAID_PARCEL]
# 2  [CSOP_ORDERABLE, PREPAID_PARCEL]
# 3  [CSOP_ORDERABLE, PREPAID_PARCEL]
# 4  [CSOP_ORDERABLE, PREPAID_PARCEL]
#
#                                          moreInfoUrl  \
# 0  https://www.colruyt.be/nl/colruyt-openingsuren...
# 1  https://www.colruyt.be/nl/colruyt-openingsuren...
# 2  https://www.colruyt.be/nl/colruyt-openingsuren...
# 3  https://www.colruyt.be/nl/colruyt-openingsuren...
# ...

# %%
import unittest

class TestStringMethods(unittest.TestCase):
    def test_upper(self):
        self.assertEqual('foo'.upper(), 'FOO')

        
    def test_isupper(self):
        self.assertTrue('FOO'.isupper())
        self.assertFalse('Foo'.isupper())

        
    def test_split(self):
        s = 'hello world'
        self.assertEqual(s.split(), ['hello', 'world'])
        # check that s.split fails when the separator is not a string
        with self.assertRaises(TypeError):
            s.split(2)
        

            
if __name__ == '__main__':
    unittest.main()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# _pydevd_bundle/pydevd_cython.pyx in _pydevd_bundle.pydevd_cython.ThreadTracer.__call__()
#
# KeyError: 'C:\\Users\\dmh8w17\\Anaconda3\\lib\\argparse.py'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\debugpy\_vendored\pydevd\pydevd_file_utils.py in get_abs_path_real_path_and_base_from_frame(frame, NORM_PATHS_AND_BASE_CONTAINER)
#     864     try:
# --> 865         return NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
#     866     except:
#
# KeyError: 'C:\\Users\\dmh8w17\\Anaconda3\\lib\\argparse.py'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import unittest
  
class SimpleTest(unittest.TestCase):
  
    # Returns True or False. 
    def test(self):        
        self.assertTrue(True)
  
if __name__ == '__main__':
    unittest.main()
# Out:
# usage: ipykernel_launcher.py [-h] [-v] [-q] [--locals] [-f] [-c] [-b]
#                              [-k TESTNAMEPATTERNS]
#                              [tests ...]
# ipykernel_launcher.py: error: argument -f/--failfast: ignored explicit argument 'C:\\Users\\dmh8w17\\AppData\\Local\\Temp\\tmp-23268Uvrs9RZJ6ysx.json'
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\dmh8w17\Anaconda3\lib\argparse.py", line 1853, in parse_known_args
#     namespace, args = self._parse_known_args(args, namespace)
#   File "C:\Users\dmh8w17\Anaconda3\lib\argparse.py", line 2062, in _parse_known_args
#     start_index = consume_optional(start_index)
#   File "C:\Users\dmh8w17\Anaconda3\lib\argparse.py", line 1984, in consume_optional
#     raise ArgumentError(action, msg % explicit_arg)
# ...

# %%
import unittest

class SimpleTest(unittest.TestCase):
  
    # Returns True or False. 
    def test(self):        
        self.assertTrue(1>2,'bakaks')
        
if __name__ == '__main__':
    #a=SimpleTest()
#a.test()
    unittest.main()
# Out:
# usage: ipykernel_launcher.py [-h] [-v] [-q] [--locals] [-f] [-c] [-b]
#                              [-k TESTNAMEPATTERNS]
#                              [tests ...]
# ipykernel_launcher.py: error: argument -f/--failfast: ignored explicit argument 'C:\\Users\\dmh8w17\\AppData\\Local\\Temp\\tmp-23268Uvrs9RZJ6ysx.json'
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\dmh8w17\Anaconda3\lib\argparse.py", line 1853, in parse_known_args
#     namespace, args = self._parse_known_args(args, namespace)
#   File "C:\Users\dmh8w17\Anaconda3\lib\argparse.py", line 2062, in _parse_known_args
#     start_index = consume_optional(start_index)
#   File "C:\Users\dmh8w17\Anaconda3\lib\argparse.py", line 1984, in consume_optional
#     raise ArgumentError(action, msg % explicit_arg)
# ...
